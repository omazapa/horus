# %%
import requests
from IPython.display import display, HTML
import urllib.parse

# %%
from payload import payload

# %%
# Definir los headers
headers = {
    "accept": "application/json, text/plain, */*",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "es-CO,es;q=0.9,en-US;q=0.8,en;q=0.7,es-ES;q=0.6,es-419;q=0.5",
    "content-length": "3798225",
    "content-type": "application/json",
    "origin": "https://horus.unal.edu.co",
    "priority": "u=1, i",
    "referer": "https://horus.unal.edu.co/institution/Universidad%20Nacional%20de%20Colombia/resource/productsList?page=2",
    "sec-ch-ua": '"Not(A:Brand";v="99", "Google Chrome";v="133", "Chromium";v="133"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Linux"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36"
}

# %%
payload["filter"].keys()
payload["filter"]["page"]=3

# %%
req=requests.post("https://horus.unal.edu.co/api_inv/investigation/products_list",headers=headers,json=payload)
req
# Out:
# <Response [200]>

# %%
data=req.json()

# %%
work=data["A"]["publications_list"][1]

# %%
work["dc:contributor:author"]

# %%
author=work["dc:contributor:author"][0]
author
# Out:
# {'_id': 2373,
#  'dc:name': 'Reyes Villamil Milton Armando',
#  'is-in': True,
#  'dc:institution': 'Universidad Nacional de Colombia',
#  'dc:campus': 'Bogotá',
#  'dc:faculty': 'FACULTAD DE CIENCIAS - 2',
#  'dc:department': 'Departamento de Matemáticas - 2',
#  'dc:gender': 'M',
#  'dc:image': '',
#  'dc:state': 'Activo',
#  'dc:date': ['1983-09-15T00:00:00.000Z', '2015-01-19T00:00:00.000Z', '']}

# %%
author_url="https://horus.unal.edu.co/institution/Universidad%20Nacional%20de%20Colombia/campus/{}/faculty/{}/uab/{}/author/{}/resource/productsList"

# %%
name=author['dc:name']
faculty=author['dc:faculty']
department=author['dc:department']
campus=author['dc:campus']

url=author_url.format(campus,faculty,department,name)
url
# Out:
# 'https://horus.unal.edu.co/institution/Universidad%20Nacional%20de%20Colombia/campus/Bogotá/faculty/FACULTAD DE CIENCIAS - 2/uab/Departamento de Matemáticas - 2/author/Reyes Villamil Milton Armando/resource/productsList'

# %%
req=requests.get(url)
req
# Out:
# <Response [200]>

# %%
HTML(req.text)
# Out:
# <!doctype html><html lang="es"><head><meta charset="utf-8"/><link href="/favicon.ico" rel="icon"/><meta content="width=device-width,initial-scale=1" name="viewport"/><meta content="#000000" name="theme-color"/><meta content="Visualización de la capacidad investigativa y producción científica de la Universidad Nacional de Colombia." name="description"/><link href="/logo.png" rel="apple-touch-icon"/><link href="/manifest.json" rel="manifest"/><link href="https://unpkg.com/leaflet/dist/leaflet.css" rel="stylesheet"/><link href="https://unpkg.com/react-leaflet-markercluster/dist/styles.min.css" rel="stylesheet"/><title>HORUS Visibilidad Científica y Tecnológica UNAL</title><script type="application/ld+json">{"@context": "https://schema.org", "@type": "Organization", "url": "https://horus.unal.edu.co", "logo": "https://horus.unal.edu.co/logo.png", "name": "HORUS Visibilidad Científica y Tecnológica UNAL", "description": "Visualización de la capacidad investigativa y producción científica 
# ...

# %%
req.text
# Out:
# '<!doctype html><html lang="es"><head><meta charset="utf-8"/><link href="/favicon.ico" rel="icon"/><meta content="width=device-width,initial-scale=1" name="viewport"/><meta content="#000000" name="theme-color"/><meta content="Visualización de la capacidad investigativa y producción científica de la Universidad Nacional de Colombia." name="description"/><link href="/logo.png" rel="apple-touch-icon"/><link href="/manifest.json" rel="manifest"/><link href="https://unpkg.com/leaflet/dist/leaflet.css" rel="stylesheet"/><link href="https://unpkg.com/react-leaflet-markercluster/dist/styles.min.css" rel="stylesheet"/><title>HORUS Visibilidad Científica y Tecnológica UNAL</title><script type="application/ld+json">{"@context": "https://schema.org", "@type": "Organization", "url": "https://horus.unal.edu.co", "logo": "https://horus.unal.edu.co/logo.png", "name": "HORUS Visibilidad Científica y Tecnológica UNAL", "description": "Visualización de la capacidad investigativa y producción científica
# ...
